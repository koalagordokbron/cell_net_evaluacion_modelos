# %% [markdown]
# # Práctica de evaluación de modelos
#
# Autor: *Pablo Morcillo Cuenca*
#
# Fecha: *26/01/2026*

# %% [markdown]
# ## Primera parte: evaluación multiclase

# %% [markdown]
# Estos son los resultados obtenidos:
#
# ![image.png](attachment:image.png)
#
#                 precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00        15
#      Benigno       1.00      0.87      0.93        15
#      Maligno       0.88      1.00      0.94        15
#
#     accuracy                           0.96        45
#     macro avg      0.96      0.96      0.96        45
#     weighted avg   0.96      0.96      0.96        45

# %% [markdown]
# ### Cálculo a mano de los valores obtenidos en el report

# %% [markdown]
# Para realizar esta parte lo haremos guiándonos con esta imagen:
#
# ![](https://miro.medium.com/v2/resize:fit:1100/format:webp/0*3v1BHxRj_JJ6Mzuz.png)

# %% [markdown]
# Con la matriz de confusión anterior y esta guía, obtenemos los siguientes valores:
#
# **1. Normal**
# - TP: 15
# - TN: 13+2+0+15=30
# - FP: 0+0=0
# - FN: 0+0=0
#
# **2. Benigno**
# - TP: 13
# - TN: 15+0+0+15=30
# - FP: 0+0=0
# - FN: 0+2=2
#
# **3. Maligno**
# - TP: 15
# - TN: 15+0+0+13=28
# - FP: 0+2=2
# - FN: 0+0=0

# %% [markdown]
# ### *Índice de métricas:*

# %% [markdown]
# **1. Precision**: de todos los que dijimos que eran SÍ, ¿cuántos lo eran?
# $$
# \frac{TP}{TP+FP}
# $$
#
# **2. Recall**: de todos los eran SÍ, ¿cuántos detectamos?
# $$
# \frac{TP}{TP+FN}
# $$
#
# **3. F1-Score**: Equibilibrio entre *precision* y *recall*.
# $$
# 2 \times \frac{Precision \times Recall}{Precision + Recall}
# $$
#
# **4. Accuracy**: aciertos totales.
# $$
# \frac{TP+TN}{TP+TN+FP+FN}
# $$

# %% [markdown]
# Ahora calculamos para cada clase:

# %% [markdown]
# ### Normal

# %% [markdown]
# $$
# \text{Precision} = \frac{15}{15+0} = 1
# $$

# %% [markdown]
# $$
# \text{Recall} = \frac{15}{15+0} = 1
# $$

# %% [markdown]
# $$
# \text{F1-Score} = 2\times\frac{1\times1}{1+1} = 1
# $$

# %% [markdown]
# $$
# \text{Accuracy} = \frac{15+30}{15+30+0+0} = 1
# $$

# %% [markdown]
# ### Benigno

# %% [markdown]
# $$
# \text{Precision} = \frac{13}{13+0} = 1
# $$

# %% [markdown]
# $$
# \text{Recall} = \frac{13}{13+2} = 0.866
# $$

# %% [markdown]
# $$
# \text{F1-Score} = 2\times\frac{1\times0.8666}{1+0.866} = 0.928
# $$

# %% [markdown]
# $$
# \text{Accuracy} = \frac{13+30}{13+30+0+2} = 0.955
# $$

# %% [markdown]
# $$
# \text{Precision} = \frac{15}{15+0} = 1
# $$

# %% [markdown]
# $$
# \text{Recall} = \frac{15}{15+0} = 1
# $$

# %% [markdown]
# $$
# \text{F1-Score} = 2\times\frac{1\times1}{1+1} = 1
# $$

# %% [markdown]
# $$
# \text{Accuracy} = \frac{15+30}{15+30+0+0} = 1
# $$

# %% [markdown]
# ### Maligno

# %% [markdown]
# $$
# \text{Precision} = \frac{15}{15+2} = 0.882
# $$

# %% [markdown]
# $$
# \text{Recall} = \frac{15}{15+0} = 1
# $$

# %% [markdown]
# $$
# \text{F1-Score} = 2\times\frac{0.882\times1}{0.882+1} = 0.937
# $$

# %% [markdown]
# $$
# \text{Accuracy} = \frac{15+28}{15+28+2+0} = 0.955
# $$

# %% [markdown]
# Tras obtener los resultados y compararlos con los datos generados por el algoritmo, vemos que son muy parecidos (no son exactamente iguales porque el programa seguramente redondeará), lo cual quiere decir que hemos hecho los cálculos bien.
